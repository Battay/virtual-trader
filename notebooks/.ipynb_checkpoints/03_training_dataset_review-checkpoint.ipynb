# %% [markdown]
# # Training dataset review
# This notebook builds one symbol dataset through production code, then verifies chronological boundaries and training-only scaling. Current local history may correctly produce an insufficient-history result.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()

if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
print("Python executable:", sys.executable)

# %%
import pandas as pd

from data_pipeline.src.config import PROCESSED_SYMBOLS_DIR
from feature_engineering.dataset_builder import build_symbol_datasets
from feature_engineering.preprocessing import fit_training_scaler
from feature_engineering.splitting import chronological_split

selected_symbol = "MCB"
minimum_usable_rows = 252
metrics = build_symbol_datasets(symbols=[selected_symbol], minimum_usable_rows=minimum_usable_rows)
metrics.to_dict()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2
# ----> 3 from data_pipeline.src.config import PROCESSED_SYMBOLS_DIR
#       4 from feature_engineering.dataset_builder import build_symbol_datasets
#       5 from feature_engineering.preprocessing import fit_training_scaler
#       6 from feature_engineering.splitting import chronological_split
#
# ModuleNotFoundError: No module named 'data_pipeline'

# %%
dataset_path = PROCESSED_SYMBOLS_DIR / f"{selected_symbol}.csv"
if not dataset_path.exists():
    raise RuntimeError(
        f"{selected_symbol} is not ready: collect enough history and rebuild before splitting."
    )
dataset = pd.read_csv(dataset_path, dtype={"symbol": "string"})
split = chronological_split(dataset, scope="symbol")
split.metadata

# %%
train_dates = set(pd.to_datetime(split.train["date"]))
validation_dates = set(pd.to_datetime(split.validation["date"]))
test_dates = set(pd.to_datetime(split.test["date"]))
assert train_dates.isdisjoint(validation_dates | test_dates)
assert validation_dates.isdisjoint(test_dates)
assert max(train_dates) < min(validation_dates) < min(test_dates)
"No date overlap or future leakage detected"

# %%
scaled = fit_training_scaler(split.train, split.validation, split.test)
pd.DataFrame({
    "feature": scaled.scaled_features,
    "training_mean_before_scaling": scaled.scaler.mean_,
    "training_scale": scaled.scaler.scale_,
}).head(20)

# %%
comparison = pd.DataFrame({
    "unscaled_close": split.validation["close"].head().to_numpy(),
    "scaled_close": scaled.validation["close"].head().to_numpy(),
})
comparison

# %% [markdown]
# The scaler is fitted only on `split.train`; validation and test partitions call `transform` with that fixed training scaler. Symbol/date/status identity columns are not scaled.
